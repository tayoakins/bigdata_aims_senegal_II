# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Principal Component Analysis

# %%
x=np.random.normal(0.0,3.5,501)
y=np.random.normal(0.0,0.5,501)
theta=-np.pi/6.0
x2=x*np.cos(theta)+y*np.sin(theta)
y2=y*np.cos(theta)-x*np.sin(theta)

# %%
plt.figure(figsize=(12,7))
plt.scatter(x2,y2)
plt.axis('scaled')
# Out:
# (-15.0, 10.0, -6.0, 6.0)

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
pca.fit(np.c_[x2,y2])
# Out:
# PCA(copy=True, n_components=2, whiten=False)

# %%
vector=pca.components_
vector
# Out:
# array([[-0.86915692, -0.4945364 ],
#        [ 0.4945364 , -0.86915692]])

# %%
plt.figure(figsize=(10,7))
plt.scatter(x2,y2)
plt.axis('scaled')
plt.quiver(np.mean(x2),np.mean(y2),vector[0][0],vector[0][1],angles='xy',scale=5.0,color='r')
plt.quiver(np.mean(x2),np.mean(y2),vector[1][0],vector[1][1],angles='xy',scale=10.0,color='r')

# %%
pca.explained_variance_ratio_
# Out:
# array([ 0.97817471,  0.02182529])

# %%
pca.get_covariance()
# Out:
# array([[ 8.55226723,  4.72341039],
#        [ 4.72341039,  2.93833074]])

# %%
x=pca.transform(np.c_[x2,y2])

# %%
plt.scatter(x.T[0],x.T[1])
plt.axis('scaled')
# Out:
# (-15.0, 15.0, -2.0, 2.0)

# %%
pca.fit_transform(np.c_[x2,y2])
# Out:
# array([[-5.03554063, -0.48723744],
#        [-2.42714696, -0.15621618],
#        [ 3.32451292,  0.46993644],
#        ...,
#        [-3.16373331,  0.16326554],
#        [-2.9159829 ,  0.41987495],
#        [-2.85162463, -0.07134453]])
